# %%
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd

# %%
train = pd.read_csv(r'C:\Users\UPENDRA\Desktop\HAR_datset\csv_files\train.csv')
test = pd.read_csv(r'C:\Users\UPENDRA\Desktop\HAR_datset\csv_files\test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
# ...

# %%
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# %%
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

# %%
print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %%
import itertools
import matplotlib.pyplot as plt
from sklearn import metrics

plt.rcParams["font.family"] = 'DejaVu Sans'
def plot_confusion_matrix(cm,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']
    classes=labels
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def perform_model(y_test,y_pred):

    # calculate overall accuracy of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    print('Accuracy    : ',accuracy)
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm , normalize=True, title='Normalized confusion matrix', cmap = plt.cm.Greens)
    plt.show()
    
    # get classification report
    print(' Classifiction Report :')
    classification_report = metrics.classification_report(y_test, y_pred)
    print(classification_report)

# %% [markdown]
# # 1. Logistic Regression with Grid Search

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
# start Grid search
parameters = {'C':[10**-3, 10**-2, 10**0, 10**2,10**3,10**4], 'penalty':['l2','l1']}
log_reg = LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=5, verbose=1, n_jobs=-1)
grid_result=log_reg_grid.fit(X_train, y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   42.4s finished
# Best: 0.934175 using {'C': 1, 'penalty': 'l2'}

# %%
lr = LogisticRegression(C=1)
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
perform_model(y_test,y_pred)
# Out:
# Accuracy    :  0.9579233118425518
#  Classifiction Report :
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.87      0.92       491
#           STANDING       0.90      0.97      0.93       532
#            WALKING       0.95      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.96      0.97       420
#   WALKING_UPSTAIRS       0.96      0.95      0.96       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %% [markdown]
# #  2. Linear SVC with GridSearch

# %%
from sklearn.svm import LinearSVC

# %%
parameters = {'C':[10**-3, 10**-2, 10**0, 10**2,10**3,10**4]}
lr_svc = LinearSVC()
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
grid_result = lr_svc_grid.fit(X_train, y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  1.3min finished
# Best: 0.940296 using {'C': 1}

# %%
lr_svc = LinearSVC(C=1)
lr_svc.fit(X_train,y_train)
y_pred = lr_svc.predict(X_test)
perform_model(y_test,y_pred)
# Out:
# Accuracy    :  0.9633525619273838
#  Classifiction Report :
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.85      0.91       491
#           STANDING       0.89      0.98      0.93       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.97      0.96      0.96      2947

# %% [markdown]
# # 3. Extra Tress  Classifier with GridSearch

# %%
from sklearn.ensemble import ExtraTreesClassifier
params = {'n_estimators':[10,20,50,100,300,500],'max_depth':[5,15,30,50,100]}
etc = ExtraTreesClassifier()
etc_grid = GridSearchCV(etc, param_grid=params, n_jobs=-1)
grid_result = etc_grid.fit(X_train, y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.931859 using {'max_depth': 50, 'n_estimators': 500}

# %%
etc = ExtraTreesClassifier(max_depth=50,n_estimators=500)
etc.fit(X_train,y_train)
y_pred = etc.predict(X_test)
perform_model(y_test,y_pred)
# Out:
# Accuracy    :  0.9412962334577536
#  Classifiction Report :
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.89      0.93       491
#           STANDING       0.91      0.98      0.94       532
#            WALKING       0.92      0.97      0.94       496
# WALKING_DOWNSTAIRS       0.96      0.85      0.90       420
#   WALKING_UPSTAIRS       0.90      0.94      0.92       471
#
#           accuracy                           0.94      2947
#          macro avg       0.94      0.94      0.94      2947
#       weighted avg       0.94      0.94      0.94      2947

# %% [markdown]
# # 4. xgbooost classifier with GridSearch

# %%
import xgboost as xgb
param_grid= {'n_estimators':[10,20,50,100,300,500],'max_depth':[3,5,7,11,17,21]}
gbdt = xgb.XGBClassifier(objective='binary:logistic')
gbdt_grid = GridSearchCV(gbdt, param_grid=param_grid, n_jobs=-1)
grid_result = gbdt_grid.fit(X_train, y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# %%
gbdt = xgb.XGBClassifier()
gbdt.fit(X_train,y_train)
y_pred = gbdt.predict(X_test)
perform_model(y_test,y_pred)
# Out:
# Accuracy    :  0.9389209365456397
#  Classifiction Report :
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.94      0.85      0.90       491
#           STANDING       0.88      0.95      0.91       532
#            WALKING       0.92      0.98      0.95       496
# WALKING_DOWNSTAIRS       0.97      0.91      0.94       420
#   WALKING_UPSTAIRS       0.93      0.92      0.92       471
#
#           accuracy                           0.94      2947
#          macro avg       0.94      0.94      0.94      2947
#       weighted avg       0.94      0.94      0.94      2947

# %%
from prettytable import PrettyTable    
x = PrettyTable()
x.field_names = ["Classifier", "Accuracy"]
x.add_row(["LogisticRegression",0.9579])
x.add_row(["LinearSvc",0.9633])
x.add_row(["ExtraTreesClassifier",0.9412])
x.add_row(["xgboost",0.9389])
print(x)
# Out:
# +----------------------+----------+
# |      Classifier      | Accuracy |
# +----------------------+----------+
# |  LogisticRegression  |  0.9579  |
# |      LinearSvc       |  0.9633  |
# | ExtraTreesClassifier |  0.9412  |
# |       xgboost        |  0.9389  |
# +----------------------+----------+

# %% [markdown]
# > We can choose  ___Linear SVC___

# %% [markdown]
# # Conclusion :
# In the real world, domain-knowledge, EDA and feature-engineering matter most.
